# %%
from scouting.data_transform.game_data import get_game_spadl_events_data, get_cards_and_substitutions

game_data = get_game_spadl_events_data("Champions League", 2024, 1866220) # Salzbourg - Brest
cards_and_substitutions = get_cards_and_substitutions("Champions League", 2024, 1866220)

# %%
from scouting.visualisations.misc import plot_events_on_pitch

plot_events_on_pitch(game_data)

# %%
game_data.type_name.value_counts()

# %%
cards_and_substitutions

# %%
# from scouting.constants import ROOT_PATH

# game_data.to_parquet(ROOT_PATH / "tests" / "spadl_salzbourg_sb29_game_data.parquet")
# cards_and_substitutions.to_parquet(ROOT_PATH / "tests" / "cards_and_subs_salzbourg_sb29_game_data.parquet")
